# %%
from datetime import datetime, timedelta
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer
import time
import tweepy

# %%
# Read in the consumer key, consumer secret, access token, and access token secret.
consumer_key = open("../../auth/twitter/consumer_key.txt").read()[:-1]
consumer_secret = open("../../auth/twitter/consumer_secret.txt").read()[:-1]
access_token = open("../../auth/twitter/access_token.txt").read()[:-1]
access_token_secret = open("../../auth/twitter/access_token_secret.txt").read()[:-1]

auth = tweepy.OAuthHandler(consumer_key = consumer_key,
                           consumer_secret = consumer_secret)
auth.set_access_token(access_token,
                      access_token_secret)

api = tweepy.API(auth)

current_time = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
cutoff_time = (datetime.utcnow() - timedelta(days = 1)).strftime("%Y-%m-%d %H:%M:%S")

# %%
# Set the users of interest.
users = ['nytimes',
        'thesun',
        'thetimes',
        'ap',
        'cnn',
        'bbcnews',
        'cnet',
        'msnuk',
        'telegraph',
        'usatoday',
        'wsj',
        'washingtonpost',
        'bostonglobe',
        'newscomauhq',
        'skynews',
        'sfgate',
        'ajenglish',
        'independent',
        'guardian',
        'latimes',
        'reutersagency',
        'abc',
        'business',
        'bw',
        'time']

# %%
def query_tweets(api, users):

    # Initialize a list to hold the tweets as JSON files.
    tweets_data = []

    # Loop over the users. (Hard to vectorize since I want to keep all tweets
    # on the same hierarchical level. I.e. I don't want a list of lists.)
    for user in range(len(users)):

        # Find the desired user.
        this_user = api.get_user(users[user])

        # Get their timeline.
        this_user_recent_tweets = api.user_timeline(user_id = this_user.id)

        # For each of their recent tweets, convert to JSON and store in a list.
        recent_tweets_json = list(map(get_tweet_json, this_user_recent_tweets))
        #recent_tweets_json = list(map(get_tweet_json, list(range(len(this_user_recent_tweets)))))

        # Append that list to the overall list of tweets.
        tweets_data += recent_tweets_json

    return(tweets_data)

# For a given user, convert a single tweet to JSON.
def get_tweet_json(tweet):
    json_str = json.dumps(tweet._json)
    tweet = json.loads(json_str)
    return(tweet)

print("Getting tweets...")

tweets_data = query_tweets(api = api, users = users)

print("Done.")
# Out:
# Getting tweets...
# Done.

# %%
#for i in range(500):
#    print(tweets_data[i]['text'])
tweets_data[13]['retweeted_status']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-151-a2c3256fc704> in <module>()
#       1 #for i in range(500):
#       2 #    print(tweets_data[i]['text'])
# ----> 3 tweets_data[13]['retweeted_status']
#
# KeyError: 'retweeted_status'

# %%
# Convert the new tweets from JSON to a tidy pandas dataframe.
def wrangle_new_tweets(new_tweets):

    # Initialize a dataframe to hold the tweets.
    tweets = pd.DataFrame()

    # Get when the tweet was created.
    tweets['created_at'] = list(map(lambda tweet: tweet['created_at'], tweets_data))

    # Get the UTC offset, so that times can be correctly compared.
    tweets['utc_offset'] = list(map(lambda tweet: tweet['user']['utc_offset'], tweets_data))

    # Get the text in the tweet.
    tweets['text'] = list(map(lambda tweet: tweet['text'], tweets_data))

    # Get the url of the tweet itself.
    tweets['tweet_url'] = list(map(get_url, tweets_data))

    # Get the user's screen name.
    tweets['screen_name'] = list(map(lambda tweet: tweet['user']['screen_name'], tweets_data))

    # Get the user's username.
    tweets['name'] = list(map(lambda tweet: tweet['user']['name'], tweets_data))

    # Get the number of times the tweet was retweeted.
    tweets['retweet_count'] = list(map(lambda tweet: tweet['retweet_count'], tweets_data))

    # Get the number of times the tweet was favorited.
    tweets['favorite_count'] = list(map(lambda tweet: tweet['favorite_count'], tweets_data))
    
    # Get the retweet status.
    tweets['is_retweet'] = list(map(check_is_retweet, tweets_data))
    
    # Get the URL to the linked page, if there is one.
    #tweets['url_ext'] = list(map(lambda tweet: tweet['entities']['urls'][0]['url'], tweets_data))

    return(tweets)

# Get the URL of a tweet even if it's a retweet.
def get_url(tweet):
    return("https://twitter.com/" + tweet['user']['screen_name'] + "/status/" + tweet['id_str'])

# Check if a tweet is a retweet.
def check_is_retweet(tweet):
    try:
        exists = tweet['retweeted_status']
        return True
    except:
        return False

tidy_new_tweets = wrangle_new_tweets(new_tweets = tweets_data)

# %%
# Read in the previously stored tweets.
old_tweets = pd.read_csv('../data/candidate_tweets.csv')

# Combine the new data with the old data, and remove duplicate tweets.
all_tweets = (tidy_new_tweets.append(other = old_tweets)
                             .drop_duplicates(subset = 'tweet_url')
                             .reset_index(drop = True))

# %%
def remove_old_tweets(all_tweets, cutoff):

    # Convert the created_at variable to a timestamp.
    all_tweets['created_at_stamp'] = all_tweets.apply(tweet_time_to_timestamp, 1)

    # Remove all tweets that are older than the cutoff. (Default 24 hours.)
    all_tweets = all_tweets[all_tweets['created_at_stamp'] > cutoff]

    # Reorder the tweets by their creation time.
    all_tweets = all_tweets.sort_values(by = 'created_at_stamp', ascending = False)

    # Reset the index.
    all_tweets = all_tweets.reset_index(drop = True)

    return(all_tweets)

# Convert the time of a tweet to a UTC timestamp.
def tweet_time_to_timestamp(tweet):
    newtime = datetime.strptime(
        tweet['created_at'], '%a %b %d %H:%M:%S +0000 %Y'
    )
    return(newtime)

# Remove any tweets that are older than 24 hours.
recent_tweets = remove_old_tweets(all_tweets, cutoff = cutoff_time)

# %%
# Save the updated, pruned dataset to csv.
recent_tweets.to_csv('../data/candidate_tweets.csv', index = False)

# %%
vectorizer = CountVectorizer(max_df=100,
                             max_features=200,
                             min_df=1,
                             stop_words='english')

# %%
tweet_texts = recent_tweets['text']

# %%
X = vectorizer.fit_transform(tweet_texts)

# %%
km = KMeans(n_clusters=2,
            init='k-means++',
            max_iter=100,
            n_init=10,
            verbose=False)

# %%
km.fit(X)
# Out:
# Initialization complete
# Iteration  0, inertia 1290.000
# Iteration  1, inertia 1237.909
# Iteration  2, inertia 1225.970
# Iteration  3, inertia 1217.078
# Iteration  4, inertia 1212.692
# Iteration  5, inertia 1208.849
# Iteration  6, inertia 1204.772
# Iteration  7, inertia 1204.437
# Converged at iteration 7: center shift 0.000000e+00 within tolerance 1.330728e-06
# Initialization complete
# Iteration  0, inertia 1278.000
# Iteration  1, inertia 1124.914
# Iteration  2, inertia 1122.843
# Converged at iteration 2: center shift 0.000000e+00 within tolerance 1.330728e-06
# Initialization complete
# Iteration  0, inertia 1292.000
# Iteration  1, inertia 1224.598
# Iteration  2, inertia 1196.126
# Iteration  3, inertia 1168.883
# Iteration  4, inertia 1159.423
# Iteration  5, inertia 1157.834
# Converged at iteration 5: center shift 0.000000e+00 within tolerance 1.330728e-06
# Initialization complete
# Iteration  0, inertia 1271.000
# Iteration  1, inertia 1207.209
# Iteration  2, inertia 1161.567
# Iteration  3, inertia 1148.284
# Iteration  4, inertia 1139.759
# Iteration  5, inertia 1119.758
# Iteration  6, inertia 1115.429
# Converged at iteration 6: center shift 0.000000e+00 within tolerance 1.330728e-06
# Initialization complete
# Iteration  0, inertia 1285.000
# Iteration  1, inertia 1221.476
# Iteration  2, inertia 1208.329
# Iteration  3, inertia 1203.128
# Iteration  4, inertia 1202.810
# Iteration  5, inertia 1202.604
# Converged at iteration 5: center shift 0.000000e+00 within tolerance 1.330728e-06
# Initialization complete
# Iteration  0, inertia 2155.000
# Iteration  1, inertia 1163.657
# Iteration  2, inertia 1159.753
# Converged at iteration 2: center shift 0.000000e+00 within tolerance 1.330728e-06
# Initialization complete
# Iteration  0, inertia 1722.000
# Iteration  1, inertia 1219.684
# Iteration  2, inertia 1191.598
# Iteration  3, inertia 1158.060
# Iteration  4, inertia 1150.541
# Converged at iteration 4: center shift 0.000000e+00 within tolerance 1.330728e-06
# Initialization complete
# Iteration  0, inertia 1659.000
# Iteration  1, inertia 1168.733
# Iteration  2, inertia 1165.497
# Converged at iteration 2: center shift 0.000000e+00 within tolerance 1.330728e-06
# Initialization complete
# Iteration  0, inertia 1266.000
# Iteration  1, inertia 1174.898
# Iteration  2, inertia 1165.611
# Converged at iteration 2: center shift 0.000000e+00 within tolerance 1.330728e-06
# Initialization complete
# Iteration  0, inertia 1275.000
# Iteration  1, inertia 1149.404
# Iteration  2, inertia 1137.506
# Iteration  3, inertia 1129.854
# Iteration  4, inertia 1128.664
# Converged at iteration 4: center shift 0.000000e+00 within tolerance 1.330728e-06
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=True)

# %%
for i in np.where(km.labels_ == 4):
    print(recent_tweets.loc[i]['text'])
# Out:
# 65     Theresa May under pressure to say who will pay...
# 71     Tuesday's Sun: "Blood On His Hands" (via @Alli...
# 86     Tuesday's i: "'Dementia tax' U-turn" (via @All...
# 94     Tuesday's Mirror: "How can we ever trust Mrs U...
# 95     Tuesday's Mail: "Facebook Lets Teens See Porn"...
# 97     Tuesday's Times: "Pensioners to pay for May's ...
# 101    Tuesday's Guardian: "May's manifesto meltdown:...
# 103    Tuesday's Independent: "May's campaign in chao...
# 115    Tuesday's Telegraph: "Care cost chaos after Ma...
# 128    Tomorrow's front page: Pensioners to pay for M...
# 161    Tuesday's @Telegraph front page #tomorrowspape...
# 163    DAILY MIRROR FRONT PAGE: 'How can we ever trus...
# 166    GUARDIAN FRONT PAGE: 'May's manifesto meltdown...
# 171    May’s 'dementia tax'  U-turn https://t.co/ELir...
# 175    THE TIMES FRONT PAGE: 'Pensioners to pay for M...
# 192    Tuesday's Express: "Dementia runs in the famil...
# 195    Tuesday's Star: "Blooming Kell it's a scorcher...
# 203    Theresa May refuses to admit u-turn on Tory so...
# 219    DAILY TELEGRAPH FRONT PAGE: 'Care cost chaos a...
# 236    Theresa May was accused of being “weak and wob...
# 263    Tuesday's Metro: "Strong and stable... or weak...
# 264    Tuesday's Morning Star: "If You Don't Like My ...
# 304    FINANCIAL TIMES FRONT PAGE: 'May's U-turn on s...
# 306    "Nothing has changed from the principals on so...
# 450    Labour launch a bid to woo students, May backt...
# 480    May in U-turn on social care after facing Tory...
# Name: text, dtype: object

# %%
np.where(km.labels_ != 0)
#km.labels_
print(recent_tweets.loc[17])
print(recent_tweets.loc[30])
print(recent_tweets.loc[113])
print(recent_tweets.loc[152])
# Out:
# created_at                             Mon May 22 22:17:18 +0000 2017
# utc_offset                                                      36000
# text                Lounge room quite the fitting room https://t.c...
# tweet_url           https://twitter.com/newscomauHQ/status/8667800...
# screen_name                                               newscomauHQ
# name                                                      news.com.au
# retweet_count                                                       1
# favorite_count                                                      1
# is_retweet                                                      False
# created_at_stamp                                  2017-05-22 22:17:18
# notif_score                                                  -1.96667
# Name: 17, dtype: object
# created_at                             Mon May 22 22:12:06 +0000 2017
# utc_offset                                                     -14400
# text                RT @NYTNational: Ayisha Gomez's daughter wasn’...
# tweet_url           https://twitter.com/nytimes/status/86677872440...
# screen_name                                                   nytimes
# name                                               The New York Times
# retweet_count                                                       6
# favorite_count                                                      0
# is_retweet                                                       True
# created_at_stamp                                  2017-05-22 22:12:06
# notif_score                                                  -9997.97
# Name: 30, dtype: object
# created_at                             Mon May 22 21:44:38 +0000 2017
# utc_offset                                                       3600
# text                RT @oliviasolon: You can catch me on olivia.so...
# tweet_url           https://twitter.com/guardian/status/8667718124...
# screen_name                                                  guardian
# name                                                     The Guardian
# retweet_count                                                       8
# favorite_count                                                      0
# is_retweet                                                       True
# created_at_stamp                                  2017-05-22 21:44:38
# notif_score                                                  -9995.97
# Name: 113, dtype: object
# created_at                             Mon May 22 21:30:01 +0000 2017
# utc_offset                                                       3600
# text                BBC criticised for 'shockingly insensitive' Ia...
# tweet_url           https://twitter.com/Telegraph/status/866768133...
# screen_name                                                 Telegraph
# name                                                    The Telegraph
# retweet_count                                                       8
# favorite_count                                                      6
# is_retweet                                                      False
# created_at_stamp                                  2017-05-22 21:30:01
# notif_score                                                   10.0333
# Name: 152, dtype: object

# %%
recent_tweets
# Out:
#                          created_at  utc_offset  \
# 0    Mon May 22 22:22:02 +0000 2017        3600
# 1    Mon May 22 22:21:50 +0000 2017        3600
# 2    Mon May 22 22:21:22 +0000 2017       36000
# 3    Mon May 22 22:21:07 +0000 2017      -14400
# 4    Mon May 22 22:21:02 +0000 2017      -14400
# 5    Mon May 22 22:20:06 +0000 2017      -25200
# 6    Mon May 22 22:20:05 +0000 2017      -14400
# 7    Mon May 22 22:20:01 +0000 2017        3600
# 8    Mon May 22 22:20:01 +0000 2017        3600
# 9    Mon May 22 22:19:14 +0000 2017        3600
# 10   Mon May 22 22:19:04 +0000 2017        3600
# 11   Mon May 22 22:18:29 +0000 2017        3600
# 12   Mon May 22 22:18:29 +0000 2017        3600
# 13   Mon May 22 22:18:01 +0000 2017        3600
# 14   Mon May 22 22:17:39 +0000 2017      -14400
# 15   Mon May 22 22:17:35 +0000 2017      -14400
# 16   Mon May 22 22:17:25 +0000 2017      -14400
# 17   Mon May 22 22:17:18 +0000 2017       36000
# 18   Mon May 22 22:16:40 +0000 2017        3600
# 19   Mon May 22 22:16:13 +0000 2017      -14400
# 20   Mon May 22 22:15:10 +0000 2017      -14400
# 21   Mon May 22 22:15:06 +0000 2017      -14400
# 22   Mon May 22 22:15:02 +0000 2017      -25200
# 23   Mon May 22 22:15:00 +0000 2017        3600
# 24   Mon May 22 22:14:45 +0000 2017        3600
# 25   Mon May 22 22:13:48 +0000 2017      -14400
# 26   Mon May 22 22:13:22 +0000 2017      -14400
# 27   Mon May 22 22:13:22 +0000 2017      -14400
# 28   Mon May 22 22:13:13 +0000 2017        3600
# 29   Mon May 22 22:12:10 +0000 2017        3600
# ..                              ...         ...
# 459  Mon May 22 15:16:31 +0000 2017        3600
# 460  Mon May 22 15:00:20 +0000 2017        3600
    return(score)

recent_tweets['notif_score'] = recent_tweets.apply(compute_notif_score, 1)

np.max(recent_tweets['notif_score'])
# Out:
# 5963.0166666666664

# %%
recent_tweets.sort_values(by = "notif_score", ascending = False)
# Out:
#                          created_at  utc_offset  \
# 227  Mon May 22 21:03:14 +0000 2017      -14400
# 278  Mon May 22 20:38:59 +0000 2017      -14400
# 217  Mon May 22 21:06:35 +0000 2017      -14400
# 267  Mon May 22 20:45:03 +0000 2017      -14400
# 425  Mon May 22 18:08:47 +0000 2017      -14400
# 325  Mon May 22 20:14:09 +0000 2017      -14400
# 396  Mon May 22 19:12:02 +0000 2017      -14400
# 416  Mon May 22 18:37:35 +0000 2017        3600
# 405  Mon May 22 19:00:52 +0000 2017      -14400
# 413  Mon May 22 18:45:08 +0000 2017      -14400
# 262  Mon May 22 20:46:24 +0000 2017      -14400
# 209  Mon May 22 21:11:39 +0000 2017      -14400
# 363  Mon May 22 19:45:11 +0000 2017      -14400
# 183  Mon May 22 21:20:09 +0000 2017      -14400
# 214  Mon May 22 21:08:44 +0000 2017      -14400
# 111  Mon May 22 21:45:04 +0000 2017      -14400
# 75   Mon May 22 21:56:02 +0000 2017      -14400
# 341  Mon May 22 20:01:58 +0000 2017      -14400
# 246  Mon May 22 20:56:26 +0000 2017      -14400
# 308  Mon May 22 20:24:02 +0000 2017      -14400
# 19   Mon May 22 22:16:13 +0000 2017      -14400
# 346  Mon May 22 20:00:07 +0000 2017      -14400
# 344  Mon May 22 20:00:10 +0000 2017      -14400
# 154  Mon May 22 21:29:19 +0000 2017      -14400
# 293  Mon May 22 20:30:26 +0000 2017      -14400
# 430  Mon May 22 17:52:14 +0000 2017        3600
# 179  Mon May 22 21:21:01 +0000 2017      -14400
# 251  Mon May 22 20:53:33 +0000 2017      -14400
# 307  Mon May 22 20:24:17 +0000 2017        3600
# 67   Mon May 22 21:58:50 +0000 2017      -14400
# ..                              ...         ...
# 359  Mon May 22 19:47:29 +0000 2017      -14400
# 215  Mon May 22 21:08:38 +0000 2017      -14400
# 409  Mon May 22 18:58:07 +0000 2017      -14400
# 371  Mon May 22 19:42:34 +0000 2017      -14400
# 420  Mon May 22 18:30:28 +0000 2017      -14400
# 415  Mon May 22 18:43:02 +0000 2017      -14400
# 442  Mon May 22 16:56:04 +0000 2017      -14400
# 435  Mon May 22 17:28:06 +0000 2017      -14400
# 373  Mon May 22 19:39:54 +0000 2017      -25200
# 311  Mon May 22 20:20:11 +0000 2017      -14400
# 116  Mon May 22 21:44:20 +0000 2017        3600
# 427  Mon May 22 18:01:00 +0000 2017      -25200
# 357  Mon May 22 19:50:00 +0000 2017      -25200
# 288  Mon May 22 20:34:41 +0000 2017      -14400
# 375  Mon May 22 19:31:00 +0000 2017      -25200
# 146  Mon May 22 21:30:11 +0000 2017        3600
# 212  Mon May 22 21:09:20 +0000 2017        3600
# 403  Mon May 22 19:01:49 +0000 2017      -14400
# 280  Mon May 22 20:37:48 +0000 2017      -14400
# 113  Mon May 22 21:44:38 +0000 2017        3600
# 271  Mon May 22 20:42:08 +0000 2017      -25200
# 357  https://twitter.com/CNET/status/86674296375760...            CNET
# 288  https://twitter.com/USATODAY/status/8667542073...        USATODAY
# 375  https://twitter.com/CNET/status/86673818313595...            CNET
# 146  https://twitter.com/Independent/status/8667681...     Independent
# 212  https://twitter.com/Independent/status/8667629...     Independent
# 403  https://twitter.com/USATODAY/status/8667308358...        USATODAY
# 280  https://twitter.com/washingtonpost/status/8667...  washingtonpost
# 113  https://twitter.com/guardian/status/8667718124...        guardian
# 271  https://twitter.com/latimes/status/86675608473...         latimes
# 30   https://twitter.com/nytimes/status/86677872440...         nytimes
# 216  https://twitter.com/BostonGlobe/status/8667627...     BostonGlobe
# 457  https://twitter.com/thetimes/status/8666772892...        thetimes
# 124  https://twitter.com/TheSun/status/866770727135...          TheSun
# 12   https://twitter.com/Independent/status/8667803...     Independent
# 410  https://twitter.com/CNET/status/86672912226500...            CNET
# 438  https://twitter.com/ReutersAgency/status/86670...   ReutersAgency
# 439  https://twitter.com/ReutersAgency/status/86670...   ReutersAgency
# 475  https://twitter.com/newscomauHQ/status/8666333...     newscomauHQ
#
#                      name  retweet_count  favorite_count is_retweet  \
# 227  The Associated Press           2761            3206      False
# 278              ABC News           1071            1694      False
# 217    The New York Times           1208            1366      False
# 267                   CNN            330            1476      False
# 425  The Associated Press            793             860      False
# 325    The New York Times            485            1157      False
# 396    The New York Times            539             958      False
# 416         BBC News (UK)            579             663      False
# 405    The New York Times            581             592      False
# 413    The New York Times            601             504      False
# 262              ABC News            427             609      False
# 209                   CNN            408             613      False
# 363    The New York Times            333             594      False
# 183       Washington Post            287             625      False
# 214              ABC News            436             466      False
# 111              ABC News            245             656      False
# 75                    CNN            245             512      False
# 341       Washington Post            253             466      False
# 246                   CNN            261             438      False
# 308                   CNN            251             432      False
# 19                    CNN            228             442      False
# 346   Wall Street Journal            302             368      False
# 344    The New York Times            219             440      False
# 154       Washington Post            384             230      False
# 293    The New York Times            185             403      False
# 430    Al Jazeera English            205             377      False
# 179    The New York Times            202             368      False
# 251                   CNN            162             380      False
# 307              Sky News            276             245      False
# 67   The Associated Press            342             170      False
# ..                    ...            ...             ...        ...
# 359  The Associated Press             38               0       True
# 215             Bloomberg             37               0       True
# 409  The Associated Press             33               0       True
# 371  The Associated Press             33               0       True
# 420    The New York Times             29               0       True
# 415             USA TODAY             29               0       True
# 442  The Associated Press             25               0       True
# 435  The Associated Press             23               0       True
# 373     Los Angeles Times             22               0       True
# 311             USA TODAY             21               0       True
# 116          The Guardian             17               0       True
# 427                  CNET             17               0       True
# 357                  CNET             15               0       True
# 288             USA TODAY             14               0       True
# 375                  CNET             12               0       True
# 146       The Independent             11               0       True
# 212       The Independent             11               0       True
# 403             USA TODAY             11               0       True
# 280       Washington Post              9               0       True
# 113          The Guardian              8               0       True
# 271     Los Angeles Times              8               0       True
# 30     The New York Times              6               0       True
# 216      The Boston Globe              6               0       True
# 457   The Times of London              4               0       True
# 124               The Sun              3               0       True
# 12        The Independent              2               0       True
# 410                  CNET              2               0       True
# 438   Reuters News Agency              2               0       True
# 439   Reuters News Agency              2               0       True
